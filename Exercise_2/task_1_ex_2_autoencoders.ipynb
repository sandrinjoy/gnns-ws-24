# %% [markdown]
# ## Task 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# Autoencoder architecture

# %%
class Autoencoder(nn.Module):

    def __init__(self, input_size, bottleneck_size, hidden_size, layers):
        super(Autoencoder, self).__init__()


        # defining encoder layers
        encoder_layers = []
        input_dimen = input_size

        for _ in range(layers-1):
            encoder_layers.append(nn.Linear(input_dimen, hidden_size))
            encoder_layers.append(nn.ReLU())
            input_dimen = hidden_size
        encoder_layers.append(nn.Linear(hidden_size, bottleneck_size))

        self.encoder = nn.Sequential(*encoder_layers)
        

        # defining decoder layers
        decoder_layers = []
        input_dimen = bottleneck_size

        for _ in range(layers-1):
            decoder_layers.append(nn.Linear(input_dimen, hidden_size))
            decoder_layers.append(nn.ReLU())
            input_dimen = hidden_size
        decoder_layers.append(nn.Linear(hidden_size, input_size))

        self.decoder = nn.Sequential(*decoder_layers)


    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %% [markdown]
# To train the model

# %%
def train_model(model, data, optimizer, loss_func, epochs, device, final_model=True):

    # setting model in train mode
    model.train()

    loss = 0
    losses = []

    for epoch in range(epochs):
        model.train()

        optimizer.zero_grad()

        data = data.to(device)
        output = model(data)

        loss = loss_func(output, data)
        loss.backward()

        optimizer.step()

        if final_model:
            losses.append(loss.item())
            print(f"Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.3f}")
            
    if final_model:
        plt.plot(np.arange(1, epochs+1), losses, marker='o')
        plt.title(f'Training reconstruction error')
        plt.xlabel('epochs')
        plt.ylabel('Reconstruction error')
        plt.grid()
        plt.show()

    return loss.item()

# %% [markdown]
# Setup training data

# %%
def generate_training_data(n_samples=1000, noise=0.1):
    data, _ = make_moons(n_samples=n_samples, noise=noise)

    data = StandardScaler().fit_transform(data)
    
    data = torch.tensor(data, dtype=torch.float32)
    return data

# %% [markdown]
# Setup test data

# %%
def generate_test_data(n_samples=1000, noise=0.1):
    data, _ = make_moons(n_samples=n_samples, noise=noise, random_state=1)

    data = StandardScaler().fit_transform(data)

    data = torch.tensor(data, dtype=torch.float32)
    return data

# %% [markdown]
# ### 1.1

# %% [markdown]
# Evaluation of model's performance

# %%
def evaluate_model(model, test_data, loss_func, device):
    # set model in evaluation mode
    model.eval()

    total_loss = 0
    with torch.no_grad(): #ensure model's weights does not change
        test_data = test_data.to(device)
        y = model(test_data)

        loss = loss_func(y, test_data)
        total_loss+=loss.item()
    return total_loss/len(test_data)

# %% [markdown]
# Evaluation of hyperparamters

# %%
from sklearn.model_selection import train_test_split

def evaluate_hyperparameters(input_size, bottleneck_size, layers_list, hidden_size_list, n_samples_list, epochs_list, lr_list, device):

    results = []
    for n_samples in n_samples_list:
        data= generate_test_data(n_samples=n_samples, noise=0.1)
        train_data, test_data = train_test_split(data, train_size=0.5, random_state=1)
        
        for layers in layers_list:
            for hidden_size in hidden_size_list:
                for epochs in epochs_list:
                    for lr in lr_list:

                            model = Autoencoder(input_size=input_size, bottleneck_size=bottleneck_size, hidden_size=hidden_size, layers=layers).to(device)
                            optimizer = optimizer = optim.Adam(model.parameters(), lr=lr)
                            loss_func = nn.MSELoss()

                            train_model(model, train_data, optimizer, loss_func, epochs, device, final_model=False)

                            test_loss = evaluate_model(model, test_data, loss_func, device)
                            results.append({
                            'layers': layers,
                            'hidden_size': hidden_size,
                            'n_samples': n_samples,
                            'epochs': epochs,
                            'learning_rate': lr,
                            'test_loss': test_loss
                            })
                            print(f"layers={layers}, hidden_size={hidden_size}, n_samples={n_samples}, epochs={epochs}, lr={lr} -> test_loss: {test_loss:3f}")
                         
    return results

# %% [markdown]
# Plots evaluation of each hyperparameter

# %%
def plot_results(results, param_key):
    param_vals = sorted(set([result[param_key] for result in results]))
    
    mean_losses = []
    for val in param_vals:
        losses = [result['test_loss'] for result in results if result[param_key]==val]
        mean_losses.append(np.mean(losses))

    plt.plot(param_vals, mean_losses, marker='o')
    plt.title(f'Test reconstruction error for {param_key}')
    plt.xlabel(param_key)
    plt.ylabel('Reconstruction error')
    plt.grid()
    plt.show()

# %% [markdown]
# Initialize hyperparameter evaluation

# %%
# initializing hyperparameters as lists for evaluation
input_size=2
bottleneck_size=1
layers_list=[2, 4, 6]
hidden_size_list=[16, 32, 64]
n_samples_list=[2000, 6000, 10000] #using 50% for training
epochs_list=[10, 250, 500]
lr_list=[0.01, 0.005, 0.001]

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")


results = evaluate_hyperparameters(input_size, bottleneck_size, layers_list, hidden_size_list, n_samples_list,
                                   epochs_list, lr_list, device)


# Plot for each hyperparameter
plot_results(results, 'layers')
plot_results(results, 'hidden_size')
plot_results(results, 'n_samples')
plot_results(results, 'epochs')
plot_results(results, 'learning_rate')
# Out:
# Using cpu device
# layers=2, hidden_size=16, n_samples=2000, epochs=10, lr=0.01 -> test_loss: 0.000520
# layers=2, hidden_size=16, n_samples=2000, epochs=10, lr=0.005 -> test_loss: 0.000997
# layers=2, hidden_size=16, n_samples=2000, epochs=10, lr=0.001 -> test_loss: 0.000849
# layers=2, hidden_size=16, n_samples=2000, epochs=250, lr=0.01 -> test_loss: 0.000160
# layers=2, hidden_size=16, n_samples=2000, epochs=250, lr=0.005 -> test_loss: 0.000207
# layers=2, hidden_size=16, n_samples=2000, epochs=250, lr=0.001 -> test_loss: 0.000283
# layers=2, hidden_size=16, n_samples=2000, epochs=500, lr=0.01 -> test_loss: 0.000141
# layers=2, hidden_size=16, n_samples=2000, epochs=500, lr=0.005 -> test_loss: 0.000141
# layers=2, hidden_size=16, n_samples=2000, epochs=500, lr=0.001 -> test_loss: 0.000213
# layers=2, hidden_size=32, n_samples=2000, epochs=10, lr=0.01 -> test_loss: 0.000388
# layers=2, hidden_size=32, n_samples=2000, epochs=10, lr=0.005 -> test_loss: 0.000713
# layers=2, hidden_size=32, n_samples=2000, epochs=10, lr=0.001 -> test_loss: 0.000974
# layers=2, hidden_size=32, n_samples=2000, epochs=250, lr=0.01 -> test_loss: 0.000134
# layers=2, hidden_size=32, n_samples=2000, epochs=250, lr=0.005 -> test_loss: 0.000162
# layers=2, hidden_size=32, n_samples=2000, epochs=250, lr=0.001 -> test_loss: 0.000273
# layers=2, hidden_size=32, n_samples=2000, epochs=500, lr=0.01 -> test_loss: 0.000126
# layers=2, hidden_size=32, n_samples=2000, epochs=500, lr=0.005 -> test_loss: 0.000128
# layers=2, hidden_size=32, n_samples=2000, epochs=500, lr=0.001 -> test_loss: 0.000160
# layers=2, hidden_size=64, n_samples=2000, epochs=10, lr=0.01 -> test_loss: 0.000400
# layers=2, hidden_size=64, n_samples=2000, epochs=10, lr=0.005 -> test_loss: 0.000428
# layers=2, hidden_size=64, n_samples=2000, epochs=10, lr=0.001 -> test_loss: 0.000855
# layers=2, hidden_size=64, n_samples=2000, epochs=250, lr=0.01 -> test_loss: 0.000125
# layers=2, hidden_size=64, n_samples=2000, epochs=250, lr=0.005 -> test_loss: 0.000109
# layers=2, hidden_size=64, n_samples=2000, epochs=250, lr=0.001 -> test_loss: 0.000244
# layers=2, hidden_size=64, n_samples=2000, epochs=500, lr=0.01 -> test_loss: 0.000048
# layers=2, hidden_size=64, n_samples=2000, epochs=500, lr=0.005 -> test_loss: 0.000118
# layers=2, hidden_size=64, n_samples=2000, epochs=500, lr=0.001 -> test_loss: 0.000147
# layers=4, hidden_size=16, n_samples=2000, epochs=10, lr=0.01 -> test_loss: 0.000846
# layers=4, hidden_size=16, n_samples=2000, epochs=10, lr=0.005 -> test_loss: 0.000962
# layers=4, hidden_size=16, n_samples=2000, epochs=10, lr=0.001 -> test_loss: 0.000987
# layers=4, hidden_size=16, n_samples=2000, epochs=250, lr=0.01 -> test_loss: 0.000171
# layers=4, hidden_size=16, n_samples=2000, epochs=250, lr=0.005 -> test_loss: 0.000053
# layers=4, hidden_size=16, n_samples=2000, epochs=250, lr=0.001 -> test_loss: 0.000268
# layers=4, hidden_size=16, n_samples=2000, epochs=500, lr=0.01 -> test_loss: 0.000090
# layers=4, hidden_size=16, n_samples=2000, epochs=500, lr=0.005 -> test_loss: 0.000083
# layers=4, hidden_size=16, n_samples=2000, epochs=500, lr=0.001 -> test_loss: 0.000189
# layers=4, hidden_size=32, n_samples=2000, epochs=10, lr=0.01 -> test_loss: 0.000470
# layers=4, hidden_size=32, n_samples=2000, epochs=10, lr=0.005 -> test_loss: 0.000944
# layers=4, hidden_size=32, n_samples=2000, epochs=10, lr=0.001 -> test_loss: 0.000984
# layers=4, hidden_size=32, n_samples=2000, epochs=250, lr=0.01 -> test_loss: 0.000036
# layers=4, hidden_size=32, n_samples=2000, epochs=250, lr=0.005 -> test_loss: 0.000046
# layers=4, hidden_size=32, n_samples=2000, epochs=250, lr=0.001 -> test_loss: 0.000125
# layers=4, hidden_size=32, n_samples=2000, epochs=500, lr=0.01 -> test_loss: 0.000044
# layers=4, hidden_size=32, n_samples=2000, epochs=500, lr=0.005 -> test_loss: 0.000038
# layers=4, hidden_size=32, n_samples=2000, epochs=500, lr=0.001 -> test_loss: 0.000143
# layers=4, hidden_size=64, n_samples=2000, epochs=10, lr=0.01 -> test_loss: 0.000388
# layers=4, hidden_size=64, n_samples=2000, epochs=10, lr=0.005 -> test_loss: 0.000381
# layers=4, hidden_size=64, n_samples=2000, epochs=10, lr=0.001 -> test_loss: 0.000947
# layers=4, hidden_size=64, n_samples=2000, epochs=250, lr=0.01 -> test_loss: 0.000035
# layers=4, hidden_size=64, n_samples=2000, epochs=250, lr=0.005 -> test_loss: 0.000057
# layers=4, hidden_size=64, n_samples=2000, epochs=250, lr=0.001 -> test_loss: 0.000055
# layers=4, hidden_size=64, n_samples=2000, epochs=500, lr=0.01 -> test_loss: 0.000023
# layers=4, hidden_size=64, n_samples=2000, epochs=500, lr=0.005 -> test_loss: 0.000029
# layers=4, hidden_size=64, n_samples=2000, epochs=500, lr=0.001 -> test_loss: 0.000046
# layers=6, hidden_size=16, n_samples=2000, epochs=10, lr=0.01 -> test_loss: 0.000987
# layers=6, hidden_size=16, n_samples=2000, epochs=10, lr=0.005 -> test_loss: 0.000989
# layers=6, hidden_size=16, n_samples=2000, epochs=10, lr=0.001 -> test_loss: 0.000987
# layers=6, hidden_size=16, n_samples=2000, epochs=250, lr=0.01 -> test_loss: 0.000135
# layers=6, hidden_size=16, n_samples=2000, epochs=250, lr=0.005 -> test_loss: 0.000185
# layers=6, hidden_size=16, n_samples=2000, epochs=250, lr=0.001 -> test_loss: 0.000270
# layers=6, hidden_size=16, n_samples=2000, epochs=500, lr=0.01 -> test_loss: 0.000113
# layers=6, hidden_size=16, n_samples=2000, epochs=500, lr=0.005 -> test_loss: 0.000089
# layers=6, hidden_size=16, n_samples=2000, epochs=500, lr=0.001 -> test_loss: 0.000129
# layers=6, hidden_size=32, n_samples=2000, epochs=10, lr=0.01 -> test_loss: 0.000613
# layers=6, hidden_size=32, n_samples=2000, epochs=10, lr=0.005 -> test_loss: 0.000982
# layers=6, hidden_size=32, n_samples=2000, epochs=10, lr=0.001 -> test_loss: 0.000992
# layers=6, hidden_size=32, n_samples=2000, epochs=250, lr=0.01 -> test_loss: 0.000043
# layers=6, hidden_size=32, n_samples=2000, epochs=250, lr=0.005 -> test_loss: 0.000064
# layers=6, hidden_size=32, n_samples=2000, epochs=250, lr=0.001 -> test_loss: 0.000183
# layers=6, hidden_size=32, n_samples=2000, epochs=500, lr=0.01 -> test_loss: 0.000044
# layers=6, hidden_size=32, n_samples=2000, epochs=500, lr=0.005 -> test_loss: 0.000039
# layers=6, hidden_size=32, n_samples=2000, epochs=500, lr=0.001 -> test_loss: 0.000044
# layers=6, hidden_size=64, n_samples=2000, epochs=10, lr=0.01 -> test_loss: 0.000848
# layers=6, hidden_size=64, n_samples=2000, epochs=10, lr=0.005 -> test_loss: 0.000892
# layers=6, hidden_size=64, n_samples=2000, epochs=10, lr=0.001 -> test_loss: 0.000987
# layers=6, hidden_size=64, n_samples=2000, epochs=250, lr=0.01 -> test_loss: 0.000023
# layers=6, hidden_size=64, n_samples=2000, epochs=250, lr=0.005 -> test_loss: 0.000054
# layers=6, hidden_size=64, n_samples=2000, epochs=250, lr=0.001 -> test_loss: 0.000071
# layers=6, hidden_size=64, n_samples=2000, epochs=500, lr=0.01 -> test_loss: 0.000057
# layers=6, hidden_size=64, n_samples=2000, epochs=500, lr=0.005 -> test_loss: 0.000030
# layers=6, hidden_size=64, n_samples=2000, epochs=500, lr=0.001 -> test_loss: 0.000048
# layers=2, hidden_size=16, n_samples=6000, epochs=10, lr=0.01 -> test_loss: 0.000254
# layers=2, hidden_size=16, n_samples=6000, epochs=10, lr=0.005 -> test_loss: 0.000297
# layers=2, hidden_size=16, n_samples=6000, epochs=10, lr=0.001 -> test_loss: 0.000315
# layers=2, hidden_size=16, n_samples=6000, epochs=250, lr=0.01 -> test_loss: 0.000053
# layers=2, hidden_size=16, n_samples=6000, epochs=250, lr=0.005 -> test_loss: 0.000032
# layers=2, hidden_size=16, n_samples=6000, epochs=250, lr=0.001 -> test_loss: 0.000091
# layers=2, hidden_size=16, n_samples=6000, epochs=500, lr=0.01 -> test_loss: 0.000039
# layers=2, hidden_size=16, n_samples=6000, epochs=500, lr=0.005 -> test_loss: 0.000044
# layers=2, hidden_size=16, n_samples=6000, epochs=500, lr=0.001 -> test_loss: 0.000062
# layers=2, hidden_size=32, n_samples=6000, epochs=10, lr=0.01 -> test_loss: 0.000215
# layers=2, hidden_size=32, n_samples=6000, epochs=10, lr=0.005 -> test_loss: 0.000230
# layers=2, hidden_size=32, n_samples=6000, epochs=10, lr=0.001 -> test_loss: 0.000332
# layers=2, hidden_size=32, n_samples=6000, epochs=250, lr=0.01 -> test_loss: 0.000050
# layers=2, hidden_size=32, n_samples=6000, epochs=250, lr=0.005 -> test_loss: 0.000047
# layers=2, hidden_size=32, n_samples=6000, epochs=250, lr=0.001 -> test_loss: 0.000078
# layers=2, hidden_size=32, n_samples=6000, epochs=500, lr=0.01 -> test_loss: 0.000018
# layers=2, hidden_size=32, n_samples=6000, epochs=500, lr=0.005 -> test_loss: 0.000040
# layers=2, hidden_size=32, n_samples=6000, epochs=500, lr=0.001 -> test_loss: 0.000058
# layers=2, hidden_size=64, n_samples=6000, epochs=10, lr=0.01 -> test_loss: 0.000269
# layers=2, hidden_size=64, n_samples=6000, epochs=10, lr=0.005 -> test_loss: 0.000250
# layers=2, hidden_size=64, n_samples=6000, epochs=10, lr=0.001 -> test_loss: 0.000327
# layers=2, hidden_size=64, n_samples=6000, epochs=250, lr=0.01 -> test_loss: 0.000038
# layers=2, hidden_size=64, n_samples=6000, epochs=250, lr=0.005 -> test_loss: 0.000052
# layers=2, hidden_size=64, n_samples=6000, epochs=250, lr=0.001 -> test_loss: 0.000080
# layers=2, hidden_size=64, n_samples=6000, epochs=500, lr=0.01 -> test_loss: 0.000029
# layers=2, hidden_size=64, n_samples=6000, epochs=500, lr=0.005 -> test_loss: 0.000033
# layers=2, hidden_size=64, n_samples=6000, epochs=500, lr=0.001 -> test_loss: 0.000061
# layers=4, hidden_size=16, n_samples=6000, epochs=10, lr=0.01 -> test_loss: 0.000266
# layers=4, hidden_size=16, n_samples=6000, epochs=10, lr=0.005 -> test_loss: 0.000328
# layers=4, hidden_size=16, n_samples=6000, epochs=10, lr=0.001 -> test_loss: 0.000334
# layers=4, hidden_size=16, n_samples=6000, epochs=250, lr=0.01 -> test_loss: 0.000022
# layers=4, hidden_size=16, n_samples=6000, epochs=250, lr=0.005 -> test_loss: 0.000055
# layers=4, hidden_size=16, n_samples=6000, epochs=250, lr=0.001 -> test_loss: 0.000087
# layers=4, hidden_size=16, n_samples=6000, epochs=500, lr=0.01 -> test_loss: 0.000010
# layers=4, hidden_size=16, n_samples=6000, epochs=500, lr=0.005 -> test_loss: 0.000025
# layers=4, hidden_size=16, n_samples=6000, epochs=500, lr=0.001 -> test_loss: 0.000022
# layers=4, hidden_size=32, n_samples=6000, epochs=10, lr=0.01 -> test_loss: 0.000146
# layers=4, hidden_size=32, n_samples=6000, epochs=10, lr=0.005 -> test_loss: 0.000258
# layers=4, hidden_size=32, n_samples=6000, epochs=10, lr=0.001 -> test_loss: 0.000332
# layers=4, hidden_size=32, n_samples=6000, epochs=250, lr=0.01 -> test_loss: 0.000015
# layers=4, hidden_size=32, n_samples=6000, epochs=250, lr=0.005 -> test_loss: 0.000028
# layers=4, hidden_size=32, n_samples=6000, epochs=250, lr=0.001 -> test_loss: 0.000059
# layers=4, hidden_size=32, n_samples=6000, epochs=500, lr=0.01 -> test_loss: 0.000009
# layers=4, hidden_size=32, n_samples=6000, epochs=500, lr=0.005 -> test_loss: 0.000006
# layers=4, hidden_size=32, n_samples=6000, epochs=500, lr=0.001 -> test_loss: 0.000019
# layers=4, hidden_size=64, n_samples=6000, epochs=10, lr=0.01 -> test_loss: 0.000124
# layers=4, hidden_size=64, n_samples=6000, epochs=10, lr=0.005 -> test_loss: 0.000142
# layers=4, hidden_size=64, n_samples=6000, epochs=10, lr=0.001 -> test_loss: 0.000327
# layers=4, hidden_size=64, n_samples=6000, epochs=250, lr=0.01 -> test_loss: 0.000017
# layers=4, hidden_size=64, n_samples=6000, epochs=250, lr=0.005 -> test_loss: 0.000014
# layers=4, hidden_size=64, n_samples=6000, epochs=250, lr=0.001 -> test_loss: 0.000016
# layers=4, hidden_size=64, n_samples=6000, epochs=500, lr=0.01 -> test_loss: 0.000007
# layers=4, hidden_size=64, n_samples=6000, epochs=500, lr=0.005 -> test_loss: 0.000007
# layers=4, hidden_size=64, n_samples=6000, epochs=500, lr=0.001 -> test_loss: 0.000012
# layers=6, hidden_size=16, n_samples=6000, epochs=10, lr=0.01 -> test_loss: 0.000331
# layers=6, hidden_size=16, n_samples=6000, epochs=10, lr=0.005 -> test_loss: 0.000331
# layers=6, hidden_size=16, n_samples=6000, epochs=10, lr=0.001 -> test_loss: 0.000340
# layers=6, hidden_size=16, n_samples=6000, epochs=250, lr=0.01 -> test_loss: 0.000025
# layers=6, hidden_size=16, n_samples=6000, epochs=250, lr=0.005 -> test_loss: 0.000056
# layers=6, hidden_size=16, n_samples=6000, epochs=250, lr=0.001 -> test_loss: 0.000091
# layers=6, hidden_size=16, n_samples=6000, epochs=500, lr=0.01 -> test_loss: 0.000015
# layers=6, hidden_size=16, n_samples=6000, epochs=500, lr=0.005 -> test_loss: 0.000056
# layers=6, hidden_size=16, n_samples=6000, epochs=500, lr=0.001 -> test_loss: 0.000065
# layers=6, hidden_size=32, n_samples=6000, epochs=10, lr=0.01 -> test_loss: 0.000289
# layers=6, hidden_size=32, n_samples=6000, epochs=10, lr=0.005 -> test_loss: 0.000329
# layers=6, hidden_size=32, n_samples=6000, epochs=10, lr=0.001 -> test_loss: 0.000331
# layers=6, hidden_size=32, n_samples=6000, epochs=250, lr=0.01 -> test_loss: 0.000011
# layers=6, hidden_size=32, n_samples=6000, epochs=250, lr=0.005 -> test_loss: 0.000022
# layers=6, hidden_size=32, n_samples=6000, epochs=250, lr=0.001 -> test_loss: 0.000086
# layers=6, hidden_size=32, n_samples=6000, epochs=500, lr=0.01 -> test_loss: 0.000006
# layers=6, hidden_size=32, n_samples=6000, epochs=500, lr=0.005 -> test_loss: 0.000008
# layers=6, hidden_size=32, n_samples=6000, epochs=500, lr=0.001 -> test_loss: 0.000012
# layers=6, hidden_size=64, n_samples=6000, epochs=10, lr=0.01 -> test_loss: 0.000310
# layers=6, hidden_size=64, n_samples=6000, epochs=10, lr=0.005 -> test_loss: 0.000226
# layers=6, hidden_size=64, n_samples=6000, epochs=10, lr=0.001 -> test_loss: 0.000329
# layers=6, hidden_size=64, n_samples=6000, epochs=250, lr=0.01 -> test_loss: 0.000007
# layers=6, hidden_size=64, n_samples=6000, epochs=250, lr=0.005 -> test_loss: 0.000011
# layers=6, hidden_size=64, n_samples=6000, epochs=250, lr=0.001 -> test_loss: 0.000020
# layers=6, hidden_size=64, n_samples=6000, epochs=500, lr=0.01 -> test_loss: 0.000005
# layers=6, hidden_size=64, n_samples=6000, epochs=500, lr=0.005 -> test_loss: 0.000006
# layers=6, hidden_size=64, n_samples=6000, epochs=500, lr=0.001 -> test_loss: 0.000010
# layers=2, hidden_size=16, n_samples=10000, epochs=10, lr=0.01 -> test_loss: 0.000203
# layers=2, hidden_size=16, n_samples=10000, epochs=10, lr=0.005 -> test_loss: 0.000202
# layers=2, hidden_size=16, n_samples=10000, epochs=10, lr=0.001 -> test_loss: 0.000211
# layers=2, hidden_size=16, n_samples=10000, epochs=250, lr=0.01 -> test_loss: 0.000029
# layers=2, hidden_size=16, n_samples=10000, epochs=250, lr=0.005 -> test_loss: 0.000036
# layers=2, hidden_size=16, n_samples=10000, epochs=250, lr=0.001 -> test_loss: 0.000059
# layers=2, hidden_size=16, n_samples=10000, epochs=500, lr=0.01 -> test_loss: 0.000028
# layers=2, hidden_size=16, n_samples=10000, epochs=500, lr=0.005 -> test_loss: 0.000031
# layers=2, hidden_size=16, n_samples=10000, epochs=500, lr=0.001 -> test_loss: 0.000047
# layers=2, hidden_size=32, n_samples=10000, epochs=10, lr=0.01 -> test_loss: 0.000069
# layers=2, hidden_size=32, n_samples=10000, epochs=10, lr=0.005 -> test_loss: 0.000153
# layers=2, hidden_size=32, n_samples=10000, epochs=10, lr=0.001 -> test_loss: 0.000188
# layers=2, hidden_size=32, n_samples=10000, epochs=250, lr=0.01 -> test_loss: 0.000028
# layers=2, hidden_size=32, n_samples=10000, epochs=250, lr=0.005 -> test_loss: 0.000033
# layers=2, hidden_size=32, n_samples=10000, epochs=250, lr=0.001 -> test_loss: 0.000049
# layers=2, hidden_size=32, n_samples=10000, epochs=500, lr=0.01 -> test_loss: 0.000021
# layers=2, hidden_size=32, n_samples=10000, epochs=500, lr=0.005 -> test_loss: 0.000022
# layers=2, hidden_size=32, n_samples=10000, epochs=500, lr=0.001 -> test_loss: 0.000036
# layers=2, hidden_size=64, n_samples=10000, epochs=10, lr=0.01 -> test_loss: 0.000085
# layers=2, hidden_size=64, n_samples=10000, epochs=10, lr=0.005 -> test_loss: 0.000201
# layers=2, hidden_size=64, n_samples=10000, epochs=10, lr=0.001 -> test_loss: 0.000184
# layers=2, hidden_size=64, n_samples=10000, epochs=250, lr=0.01 -> test_loss: 0.000033
# layers=2, hidden_size=64, n_samples=10000, epochs=250, lr=0.005 -> test_loss: 0.000026
# layers=2, hidden_size=64, n_samples=10000, epochs=250, lr=0.001 -> test_loss: 0.000051
# layers=2, hidden_size=64, n_samples=10000, epochs=500, lr=0.01 -> test_loss: 0.000008
# layers=2, hidden_size=64, n_samples=10000, epochs=500, lr=0.005 -> test_loss: 0.000020
# layers=2, hidden_size=64, n_samples=10000, epochs=500, lr=0.001 -> test_loss: 0.000043
# layers=4, hidden_size=16, n_samples=10000, epochs=10, lr=0.01 -> test_loss: 0.000172
# layers=4, hidden_size=16, n_samples=10000, epochs=10, lr=0.005 -> test_loss: 0.000194
# layers=4, hidden_size=16, n_samples=10000, epochs=10, lr=0.001 -> test_loss: 0.000200
# layers=4, hidden_size=16, n_samples=10000, epochs=250, lr=0.01 -> test_loss: 0.000024
# layers=4, hidden_size=16, n_samples=10000, epochs=250, lr=0.005 -> test_loss: 0.000030
# layers=4, hidden_size=16, n_samples=10000, epochs=250, lr=0.001 -> test_loss: 0.000055
# layers=4, hidden_size=16, n_samples=10000, epochs=500, lr=0.01 -> test_loss: 0.000007
# layers=4, hidden_size=16, n_samples=10000, epochs=500, lr=0.005 -> test_loss: 0.000010
# layers=4, hidden_size=16, n_samples=10000, epochs=500, lr=0.001 -> test_loss: 0.000019
# layers=4, hidden_size=32, n_samples=10000, epochs=10, lr=0.01 -> test_loss: 0.000148
# layers=4, hidden_size=32, n_samples=10000, epochs=10, lr=0.005 -> test_loss: 0.000168
# layers=4, hidden_size=32, n_samples=10000, epochs=10, lr=0.001 -> test_loss: 0.000199
# layers=4, hidden_size=32, n_samples=10000, epochs=250, lr=0.01 -> test_loss: 0.000008
# layers=4, hidden_size=32, n_samples=10000, epochs=250, lr=0.005 -> test_loss: 0.000014
# layers=4, hidden_size=32, n_samples=10000, epochs=250, lr=0.001 -> test_loss: 0.000027
# layers=4, hidden_size=32, n_samples=10000, epochs=500, lr=0.01 -> test_loss: 0.000005
# layers=4, hidden_size=32, n_samples=10000, epochs=500, lr=0.005 -> test_loss: 0.000007
# layers=4, hidden_size=32, n_samples=10000, epochs=500, lr=0.001 -> test_loss: 0.000013
# layers=4, hidden_size=64, n_samples=10000, epochs=10, lr=0.01 -> test_loss: 0.000067
# layers=4, hidden_size=64, n_samples=10000, epochs=10, lr=0.005 -> test_loss: 0.000069
# layers=4, hidden_size=64, n_samples=10000, epochs=10, lr=0.001 -> test_loss: 0.000188
# layers=4, hidden_size=64, n_samples=10000, epochs=250, lr=0.01 -> test_loss: 0.000005
# layers=4, hidden_size=64, n_samples=10000, epochs=250, lr=0.005 -> test_loss: 0.000007
# layers=4, hidden_size=64, n_samples=10000, epochs=250, lr=0.001 -> test_loss: 0.000029
# layers=4, hidden_size=64, n_samples=10000, epochs=500, lr=0.01 -> test_loss: 0.000004
# layers=4, hidden_size=64, n_samples=10000, epochs=500, lr=0.005 -> test_loss: 0.000005
# layers=4, hidden_size=64, n_samples=10000, epochs=500, lr=0.001 -> test_loss: 0.000007
# layers=6, hidden_size=16, n_samples=10000, epochs=10, lr=0.01 -> test_loss: 0.000199
# layers=6, hidden_size=16, n_samples=10000, epochs=10, lr=0.005 -> test_loss: 0.000199
# layers=6, hidden_size=16, n_samples=10000, epochs=10, lr=0.001 -> test_loss: 0.000206
# layers=6, hidden_size=16, n_samples=10000, epochs=250, lr=0.01 -> test_loss: 0.000040
# layers=6, hidden_size=16, n_samples=10000, epochs=250, lr=0.005 -> test_loss: 0.000032
# layers=6, hidden_size=16, n_samples=10000, epochs=250, lr=0.001 -> test_loss: 0.000056
# layers=6, hidden_size=16, n_samples=10000, epochs=500, lr=0.01 -> test_loss: 0.000033
# layers=6, hidden_size=16, n_samples=10000, epochs=500, lr=0.005 -> test_loss: 0.000017
# layers=6, hidden_size=16, n_samples=10000, epochs=500, lr=0.001 -> test_loss: 0.000032
# layers=6, hidden_size=32, n_samples=10000, epochs=10, lr=0.01 -> test_loss: 0.000125
# layers=6, hidden_size=32, n_samples=10000, epochs=10, lr=0.005 -> test_loss: 0.000201
# layers=6, hidden_size=32, n_samples=10000, epochs=10, lr=0.001 -> test_loss: 0.000201
# layers=6, hidden_size=32, n_samples=10000, epochs=250, lr=0.01 -> test_loss: 0.000007
# layers=6, hidden_size=32, n_samples=10000, epochs=250, lr=0.005 -> test_loss: 0.000010
# layers=6, hidden_size=32, n_samples=10000, epochs=250, lr=0.001 -> test_loss: 0.000052
# layers=6, hidden_size=32, n_samples=10000, epochs=500, lr=0.01 -> test_loss: 0.000006
# layers=6, hidden_size=32, n_samples=10000, epochs=500, lr=0.005 -> test_loss: 0.000007
# layers=6, hidden_size=32, n_samples=10000, epochs=500, lr=0.001 -> test_loss: 0.000012
# layers=6, hidden_size=64, n_samples=10000, epochs=10, lr=0.01 -> test_loss: 0.000110
# layers=6, hidden_size=64, n_samples=10000, epochs=10, lr=0.005 -> test_loss: 0.000126
# layers=6, hidden_size=64, n_samples=10000, epochs=10, lr=0.001 -> test_loss: 0.000200
# layers=6, hidden_size=64, n_samples=10000, epochs=250, lr=0.01 -> test_loss: 0.000003
# layers=6, hidden_size=64, n_samples=10000, epochs=250, lr=0.005 -> test_loss: 0.000008
# layers=6, hidden_size=64, n_samples=10000, epochs=250, lr=0.001 -> test_loss: 0.000020
# layers=6, hidden_size=64, n_samples=10000, epochs=500, lr=0.01 -> test_loss: 0.000004
# layers=6, hidden_size=64, n_samples=10000, epochs=500, lr=0.005 -> test_loss: 0.000003
# layers=6, hidden_size=64, n_samples=10000, epochs=500, lr=0.001 -> test_loss: 0.000007

# %% [markdown]
# **Comment**

# %% [markdown]
# Initializing training of final model

# %%
# best hyperparameters
input_size = 2
bottleneck_size = 1
noise = 0.1
layers = 4
hidden_size = 64
n_samples = 3000
lr = 0.005
epochs = 200


device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

model = Autoencoder(input_size=input_size, bottleneck_size=bottleneck_size, hidden_size=hidden_size, layers=layers).to(device)
data = generate_training_data(n_samples, noise)
optimizer = optim.Adam(model.parameters(), lr=lr)
loss_func = nn.MSELoss()

train_model(model, data, optimizer, loss_func, epochs, device)
# Out:
# Using cpu device
# Epoch [1/200], Loss: 1.003
# Epoch [2/200], Loss: 1.000
# Epoch [3/200], Loss: 0.993
# Epoch [4/200], Loss: 0.973
# Epoch [5/200], Loss: 0.934
# Epoch [6/200], Loss: 0.875
# Epoch [7/200], Loss: 0.796
# Epoch [8/200], Loss: 0.685
# Epoch [9/200], Loss: 0.544
# Epoch [10/200], Loss: 0.416
# Epoch [11/200], Loss: 0.450
# Epoch [12/200], Loss: 0.463
# Epoch [13/200], Loss: 0.391
# Epoch [182/200], Loss: 0.041
# Epoch [183/200], Loss: 0.038
# Epoch [184/200], Loss: 0.039
# Epoch [185/200], Loss: 0.039
# Epoch [186/200], Loss: 0.037
# Epoch [187/200], Loss: 0.038
# Epoch [188/200], Loss: 0.037
# Epoch [189/200], Loss: 0.037
# Epoch [190/200], Loss: 0.037
# Epoch [191/200], Loss: 0.036
# Epoch [192/200], Loss: 0.037
# Epoch [193/200], Loss: 0.036
# Epoch [194/200], Loss: 0.036
# Epoch [195/200], Loss: 0.036
# Epoch [196/200], Loss: 0.035
# Epoch [197/200], Loss: 0.035
# Epoch [198/200], Loss: 0.036
# Epoch [199/200], Loss: 0.035
# Epoch [200/200], Loss: 0.035
# 0.0351426787674427

# %% [markdown]
# Results with best found hyperparameters

# %%
# best hyperparameters
noise = 0.1


data = generate_test_data(n_samples=n_samples, noise=noise)

model.eval()

with torch.no_grad():
    reconstructed_data = model(data)

plt.scatter(data[:,0], data[:,1], alpha=0.5, label="Original data")
plt.scatter(reconstructed_data[:,0],reconstructed_data[:,1], alpha=0.5, label="Reconstructed data")
plt.title("Autoencoder Reconstruction Comparison")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# %% [markdown]
# ### 1.2

# %%
import pandas as pd

# %%
def repeat_training_experiments(num_repeat, n_samples, model, epochs, device):
    # Store reconstruction errors for each experiment
    reconstruction_errors_same_data = []
    reconstruction_errors_diff_data = []
    
    # Generate fixed data for "same data" experiments
    fixed_data = generate_training_data(n_samples, noise)
    
    for _ in range(num_repeat):
        # Repeat training with the "same dataset"
        reconstruction_error_same = train_model(model, fixed_data, optimizer, loss_func, epochs, device, final_model=False)
        reconstruction_errors_same_data.append(reconstruction_error_same)
        
        # Repeat training with "different datasets"
        diff_data = generate_training_data(n_samples, noise)
        
        reconstruction_error_diff = train_model(model, diff_data, optimizer, loss_func, epochs, device, final_model=False)
        reconstruction_errors_diff_data.append(reconstruction_error_diff)
    

    return reconstruction_errors_same_data, reconstruction_errors_diff_data

# %%
num_repeat=10 # number of times experiment is repeated

errors_same, errors_diff = repeat_training_experiments(num_repeat, n_samples, model, epochs, device)

reconstruction_eror_result = {
    'Same Dataset': [np.mean(errors_same), np.std(errors_same)],
    'Different Dataset': [np.mean(errors_diff), np.std(errors_diff)]
}

df = pd.DataFrame.from_dict(reconstruction_eror_result)
df.index = ['Mean', 'Standard deviation']
print(df)

# Plot results
plt.figure(figsize=(10, 5))
plt.boxplot([errors_same, errors_diff], tick_labels=["Same Dataset", "Different Datasets"])
plt.title("Reconstruction Error Variability")
plt.ylabel("Reconstruction Error")
plt.show()
# Out:
#                     Same Dataset  Different Dataset
# Mean                    0.011362           0.011852
# Standard deviation      0.001173           0.000787

# %% [markdown]
# **comment**

# %% [markdown]
# ### 1.3

# %%
from sklearn.mixture import GaussianMixture

# %%
data, _ = make_moons(n_samples=n_samples, noise=noise)

# encode data with best found hyperparameters
with torch.no_grad():
    codes = model.encoder(torch.tensor(data, dtype=torch.float32)).numpy()

# Plot the histogram
plt.hist(codes, bins=30, density=True, ec='black', alpha=0.5)
plt.title("Histogram of Code Distribution")
plt.xlabel("Code Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Elbow Method to determine number of components for GMM

# %%
n_components_list = np.arange(1,10)
scores = []

for n in n_components_list:
    gmm = GaussianMixture(n_components=n, random_state=42)
    gmm.fit(codes)
    scores.append(gmm.score(codes))

plt.plot(n_components_list, scores, marker="o")
plt.xlabel("Number of Components")
plt.ylabel("Score")
plt.title("Elbow Method for GMM")
plt.show()

# %%
# fit a GMM with number of components
gmm = GaussianMixture(n_components=2, random_state=1)
gmm.fit(codes)

# generate synthetic samples
synthetic_codes = gmm.sample(n_samples=n_samples)[0]


plt.hist(codes, bins=30, density=True, alpha=0.5, color='blue', label='Original')
plt.hist(synthetic_codes, bins=30, density=True, ec='black', alpha=0.7, color='green', label='Synthetic')
plt.title("Comparison of Original and Synthetic Code Distributions")
plt.xlabel("Code Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
# decode synthetic codes into data space
with torch.no_grad():
    synthetic_data = model.decoder(torch.tensor(synthetic_codes, dtype=torch.float32)).numpy()

# plot original vs synthetic data
plt.scatter(data[:, 0], data[:, 1], alpha=0.5, s=10, label='Original Data')
plt.scatter(synthetic_data[:, 0], synthetic_data[:, 1], alpha=0.5, s=10, label='Synthetic Data')
plt.title("Original vs Synthetic Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# %% [markdown]
# **comment**

# %% [markdown]
# ### 1.4

# %%
noise = 0.2

test_data = generate_test_data(n_samples=n_samples, noise=noise)

with torch.no_grad():
    reconstructed_data = model(test_data)


plt.scatter(test_data[:, 0], test_data[:, 1], alpha=0.5, label="Original test data")
plt.scatter(reconstructed_data[:, 0], reconstructed_data[:, 1], alpha=0.5, label="Reconstructed Data")

# Plot formatting
plt.title(f'Autoencoder Reconstruction with Noise={noise}')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 1.5

# %%
noise = 0.2

train_data = generate_training_data(n_samples, noise)

train_model(model, train_data, optimizer, loss_func, epochs, device)

test_data = generate_test_data(n_samples=n_samples, noise=noise)

with torch.no_grad():
    reconstructed_data = model(test_data)


plt.scatter(test_data[:, 0], test_data[:, 1], alpha=0.5, label="Original test data")
plt.scatter(reconstructed_data[:, 0], reconstructed_data[:, 1], alpha=0.5, label="Reconstructed Data")

# Plot formatting
plt.title(f'Autoencoder Reconstruction with Noise={noise}')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()
# Out:
# Epoch [1/200], Loss: 0.050
# Epoch [2/200], Loss: 0.048
# Epoch [3/200], Loss: 0.051
# Epoch [4/200], Loss: 0.047
# Epoch [5/200], Loss: 0.048
# Epoch [6/200], Loss: 0.047
# Epoch [7/200], Loss: 0.049
# Epoch [8/200], Loss: 0.048
# Epoch [9/200], Loss: 0.052
# Epoch [10/200], Loss: 0.052
# Epoch [11/200], Loss: 0.058
# Epoch [12/200], Loss: 0.065
# Epoch [13/200], Loss: 0.071
# Epoch [14/200], Loss: 0.056
# Epoch [15/200], Loss: 0.053
# Epoch [16/200], Loss: 0.058
# Epoch [17/200], Loss: 0.055
# Epoch [18/200], Loss: 0.051
# Epoch [19/200], Loss: 0.053
# Epoch [20/200], Loss: 0.048
# Epoch [21/200], Loss: 0.050
# Epoch [22/200], Loss: 0.048
# Epoch [23/200], Loss: 0.048
# Epoch [24/200], Loss: 0.049
# Epoch [25/200], Loss: 0.049
# Epoch [26/200], Loss: 0.050
# Epoch [27/200], Loss: 0.048
# Epoch [28/200], Loss: 0.048
# Epoch [29/200], Loss: 0.046
# Epoch [30/200], Loss: 0.047
# Epoch [31/200], Loss: 0.047
# Epoch [32/200], Loss: 0.045
